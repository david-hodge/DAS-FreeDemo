# %% [markdown]
# # Data Exploration
# This notebook explores the survey results dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load cleaned data
df = pd.read_csv('../data/processed/survey_cleaned.csv')
df.describe()
